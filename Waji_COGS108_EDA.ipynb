# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_players_dataset.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0          player_name  height  weight         birth_date  \
# 0              0       Alaa Abdelnaby      82   240.0      June 24, 1968
# 1              1      Zaid Abdul-Aziz      81   235.0      April 7, 1946
# 2              2  Kareem Abdul-Jabbar      86   225.0     April 16, 1947
# 3              3   Mahmoud Abdul-Rauf      73   162.0      March 9, 1969
# 4              4    Tariq Abdul-Wahad      78   223.0   November 3, 1974
# ...          ...                  ...     ...     ...                ...
# 4934        4934           Ante Žižić      82   266.0    January 4, 1997
# 4935        4935             Jim Zoet      85   240.0  December 20, 1953
# 4936        4936            Bill Zopf      73   170.0       June 7, 1948
# 4937        4937          Ivica Zubac      84   240.0     March 18, 1997
# 4938        4938           Matt Zunic      75   195.0  December 19, 1919
#
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#        Unnamed: 0       height       weight  active_from    active_to  \
# count  4939.00000  4939.000000  4939.000000  4939.000000  4939.000000
# mean   2469.00000    77.997570   209.352298  1988.085442  1992.312411
# std    1425.91082     3.607684    26.082824    22.281330    23.021619
# min       0.00000    63.000000   114.000000  1947.000000  1947.000000
# 25%    1234.50000    75.000000   190.000000  1971.000000  1975.000000
# 50%    2469.00000    78.000000   210.000000  1990.000000  1995.000000
# 75%    3703.50000    81.000000   225.000000  2007.000000  2014.000000
# max    4938.00000    91.000000   360.000000  2022.000000  2022.000000
#
#            NBA_fg%  NBA_g_played      NBA_ppg      NBA_ft%     NBA_fgpg  \
# count  4900.000000   4936.000000  4936.000000  4702.000000  4936.000000
# mean      0.409447    269.628039     6.406321     0.698844     2.446252
# std       0.107935    310.394832     4.763938     0.141997     1.812034
# ...

# %%
sns.histplot(data= df['weight'], bins = 20)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.histplot(data= df['height'], bins = 20)
# Out:
# <AxesSubplot:xlabel='height', ylabel='Count'>

# %%
sns.lmplot(x= 'weight', y = 'NBA_ppg', data =df)

# %%
sns.lmplot(x= 'height', y = 'NBA_3ptapg', data =df)

# %%
sns.lmplot(x= 'height', y = 'NBA_ft%', data =df)

# %%
sns.lmplot(x= 'height', y = 'NCAA_ftapg', data =df)
