# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_players_dataset.csv')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#       Unnamed: 0          player_name  height  weight         birth_date  \
# 0              0       Alaa Abdelnaby      82   240.0      June 24, 1968
# 1              1      Zaid Abdul-Aziz      81   235.0      April 7, 1946
# 2              2  Kareem Abdul-Jabbar      86   225.0     April 16, 1947
# 3              3   Mahmoud Abdul-Rauf      73   162.0      March 9, 1969
# 4              4    Tariq Abdul-Wahad      78   223.0   November 3, 1974
# ...          ...                  ...     ...     ...                ...
# 4934        4934           Ante Žižić      82   266.0    January 4, 1997
# 4935        4935             Jim Zoet      85   240.0  December 20, 1953
# 4936        4936            Bill Zopf      73   170.0       June 7, 1948
# 4937        4937          Ivica Zubac      84   240.0     March 18, 1997
# 4938        4938           Matt Zunic      75   195.0  December 19, 1919
#
#       active_from  active_to position                   college  NBA_fg%  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'height', 'weight', 'birth_date',
#        'active_from', 'active_to', 'position', 'college', 'NBA_fg%',
#        'NBA_g_played', 'NBA_ppg', 'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg',
#        'NBA_ftpg', 'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%',
#        'NBA_efg%', 'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
#        'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
#        'NCAA_3ptapg', 'NCAA_3pt%', 'updated_birth_date'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#        Unnamed: 0       height       weight  active_from    active_to  \
# count  4939.00000  4939.000000  4939.000000  4939.000000  4939.000000
# mean   2469.00000    77.997570   209.352298  1988.085442  1992.312411
# std    1425.91082     3.607684    26.082824    22.281330    23.021619
# min       0.00000    63.000000   114.000000  1947.000000  1947.000000
# 25%    1234.50000    75.000000   190.000000  1971.000000  1975.000000
# 50%    2469.00000    78.000000   210.000000  1990.000000  1995.000000
# 75%    3703.50000    81.000000   225.000000  2007.000000  2014.000000
# max    4938.00000    91.000000   360.000000  2022.000000  2022.000000
#
#            NBA_fg%  NBA_g_played      NBA_ppg      NBA_ft%     NBA_fgpg  \
# count  4900.000000   4936.000000  4936.000000  4702.000000  4936.000000
# mean      0.409447    269.628039     6.406321     0.698844     2.446252
# std       0.107935    310.394832     4.763938     0.141997     1.812034
# ...

# %%
sns.histplot(data = df['weight'], bins = 15)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
df['NBA_seasons_played'] = df['active_to'] - df['active_from']
df.describe()
# Out:
#        Unnamed: 0       height       weight  active_from    active_to  \
# count  4939.00000  4939.000000  4939.000000  4939.000000  4939.000000
# mean   2469.00000    77.997570   209.352298  1988.085442  1992.312411
# std    1425.91082     3.607684    26.082824    22.281330    23.021619
# min       0.00000    63.000000   114.000000  1947.000000  1947.000000
# 25%    1234.50000    75.000000   190.000000  1971.000000  1975.000000
# 50%    2469.00000    78.000000   210.000000  1990.000000  1995.000000
# 75%    3703.50000    81.000000   225.000000  2007.000000  2014.000000
# max    4938.00000    91.000000   360.000000  2022.000000  2022.000000
#
#            NBA_fg%  NBA_g_played      NBA_ppg      NBA_ft%     NBA_fgpg  \
# count  4900.000000   4936.000000  4936.000000  4702.000000  4936.000000
# mean      0.409447    269.628039     6.406321     0.698844     2.446252
# std       0.107935    310.394832     4.763938     0.141997     1.812034
# ...

# %%
sns.histplot(data = df['NBA_seasons_played'], bins = 15)
# Out:
# <AxesSubplot:xlabel='NBA_seasons_played', ylabel='Count'>

# %%
sns.lmplot(
    x='height',
    y='NBA_g_played',
    data=df,
)

# %%
sns.lmplot(
    x='NCAA_fg%',
    y='NBA_g_played',
    data=df,
)

# %%
pd.options.display.float_format = '{:,.6f}'.format
df['NCAA_ft%'] = df['NCAA_ftapg'] / df['NCAA_ftapg']
df.describe()
# Out:
#         Unnamed: 0       height       weight  active_from    active_to  \
# count 4,939.000000 4,939.000000 4,939.000000 4,939.000000 4,939.000000
# mean  2,469.000000    77.997570   209.352298 1,988.085442 1,992.312411
# std   1,425.910820     3.607684    26.082824    22.281330    23.021619
# min       0.000000    63.000000   114.000000 1,947.000000 1,947.000000
# 25%   1,234.500000    75.000000   190.000000 1,971.000000 1,975.000000
# 50%   2,469.000000    78.000000   210.000000 1,990.000000 1,995.000000
# 75%   3,703.500000    81.000000   225.000000 2,007.000000 2,014.000000
# max   4,938.000000    91.000000   360.000000 2,022.000000 2,022.000000
#
#            NBA_fg%  NBA_g_played      NBA_ppg      NBA_ft%     NBA_fgpg  \
# count 4,900.000000  4,936.000000 4,936.000000 4,702.000000 4,936.000000
# mean      0.409447    269.628039     6.406321     0.698844     2.446252
# std       0.107935    310.394832     4.763938     0.141997     1.812034
# ...

# %%
sns.lmplot(
    x='NCAA_3pt%',
    y='NBA_g_played',
    data=df,
)

# %%
sns.lmplot(
    x='NCAA_ft',
    y='NBA_g_played',
    data=df,
)

# %%
sns.lmplot(
    x='NCAA_fg%',
    y='NBA_fg%',
    data=df,
)

# %%
sns.lmplot(
    x='NCAA_ft',
    y='NBA_ft%',
    data=df,
)

# %%
sns.lmplot(
    x='NCAA_3pt%',
    y='NBA_3pt%',
    data=df,
)
