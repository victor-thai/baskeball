# %%
#import pandas and seaborn library
import pandas as pd
import seaborn as sns
from datetime import datetime
import numpy as np

# %% [markdown]
# # Data Cleaning - looking through nba_players_v4.csv

# %% [markdown]
# ### Research Question
#
# Is there a relationship between a NCAA basketball player’s statistics (height, wingspan, collegiate league performance, efficiency ratings, offensive/defensive scores) and their success/player efficiency rating in the NBA?

# %%
#First let us clean the web scraped nba_players_v4 dataset, which has all the NBA and NCAA (collegiate) basketball player data.
players = pd.read_csv('nba_players_w_PER.csv')
players.head()
# Out:
#    Unnamed: 0                        url                 name  active_from  \
# 0           0  /players/a/abdelal01.html       Alaa Abdelnaby         1991
# 1           1  /players/a/abdulza01.html      Zaid Abdul-Aziz         1969
# 2           2  /players/a/abdulka01.html  Kareem Abdul-Jabbar         1970
# 3           3  /players/a/abdulma02.html   Mahmoud Abdul-Rauf         1991
# 4           4  /players/a/abdulta01.html    Tariq Abdul-Wahad         1998
#
#    active_to position                   college height  weight  \
# 0       1995      F-C                      Duke   6-10   240.0
# 1       1978      C-F                Iowa State    6-9   235.0
# 2       1989        C                      UCLA    7-2   225.0
# 3       2001        G                       LSU    6-1   162.0
# 4       2003        F  Michigan, San Jose State    6-6   223.0
#
#          birth_date  ...  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  \
# 0     June 24, 1968  ...    0.728        3.3         5.6        1.8
# 1     April 7, 1946  ...    0.645        7.8        16.8        6.7
# 2    April 16, 1947  ...    0.628       10.7        16.8        5.0
# 3     March 9, 1969  ...    0.863       10.4        21.9        5.5
# 4  November 3, 1974  ...    0.726        4.9        10.4        3.2
#
#    NCAA_ftapg  NCAA__3ptpg  NCAA__3ptapg  NCAA__3ptpct  NCAA_efgpct   PER
# 0         2.5          0.0           0.0           NaN          NaN  13.0
# 1        10.4          NaN           NaN           NaN          NaN  15.1
# 2         7.9          NaN           NaN           NaN          NaN  24.6
# 3         6.4          2.7           7.2         0.372          NaN  15.4
# 4         4.4          0.6           1.7         0.322          NaN  11.4
#
# [5 rows x 35 columns]

# %%
#Significant number of columns and listed below are the definitions of each column.
players.columns
# Out:
# Index(['Unnamed: 0', 'url', 'name', 'active_from', 'active_to', 'position',
#        'college', 'height', 'weight', 'birth_date', 'NBA_fg%', 'NBA_g_played',
#        'NBA_ppg', 'NBA_ft%', 'NBA_fg_per_game', 'NBA_fga_per_game',
#        'NBA_ft_per_g', 'NBA_fta_p_g', 'NBA__3ptpg', 'NBA__3ptapg',
#        'NBA__3ptpct', 'NBA_efgpct', 'NCAA_fgpct', 'NCAA_games', 'NCAA_ppg',
#        'NCAA_ft', 'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg',
#        'NCAA__3ptpg', 'NCAA__3ptapg', 'NCAA__3ptpct', 'NCAA_efgpct', 'PER'],
#       dtype='object')

# %% [markdown]
# The 34 columns of the dataset have the following definitions...
#
# | Column Name | Definition |
# | ----------- | ---------- |
# | 'Unnamed: 0' | excess column with no meaning, exactly the same as index|
# | 'url' | url of the player website from basketball-reference.com/ + 'url'|
# | 'name' | name of the player |
# | 'active_from' | when they started playing in NBA |
# | 'active_to' | when they stopped playing in NBA |
# | 'position' | position that they played in the NBA |
# | 'college' | college that player attended |
# | 'weight' | weight of the player |
# | 'birth_date' | birthdate of player |
# | 'NBA_fg%' | NBA field goal percent |
# | 'NBA_g_played' | NBA games played |
# | 'NBA_ppg' | NBA average points per game |
# | 'NBA_ft%' | NBA free throw percent |
# | 'NBA_fg_per_game' | NBA average field goals per game |
# | 'NBA_fga_per_game' | NBA average field goal attempts per game |
# | 'NBA_ft_per_g' | NBA averagefree throws per game |
# | 'NBA_fta_p_g' | NBA average free throws attempted per game |
# | ''NBA__3ptpg' | NBA average 3 point points per game |
# | 'NBA__3ptapg' | NBA average 3 point points attempted per game |
# | 'NBA_efgpct' | NBA effective field goal percentage |
# | 'NCAA_fgpct' | NCAA field goal percent |
# | 'NCAA_games' | NCAA games played |
# | 'NCAA_ppg' | NCAA average points per game |
# | 'NCAA_ft' | NCAA average free throws per game |
# | 'NCAA_fgpg' | NCAA averafe field goals per game |
# | 'NCAA_fgapg' | NCAA average field goal attempts per game |
# | 'NCAA_ftpg' | NCAA average free throws per game |
# | 'NCAA_ftapg' | NCAA average free throws attempted per game |
# | 'NCAA__3ptpg' | NCAA average 3 points per game |
# | 'NCAA__3ptapg' | NCAA average 3 point attempted per game |
# | 'NCAA__3ptpct' | NCAA 3 point percent |
# | 'NCAA_efgpct' | NCAA effective field goal percent |
# | 'PER' | NBA player efficiency rating |

# %%
# describing data and looking for any unique trends/patterns
players.describe()
# Out:
#         Unnamed: 0  active_from    active_to       weight      NBA_fg%  \
# count  4973.000000  4973.000000  4973.000000  4968.000000  4937.000000
# mean   2486.000000  1988.063141  1992.266037   209.326490     0.409057
# std    1435.725775    22.329240    23.075182    26.049095     0.108477
# min       0.000000  1947.000000  1947.000000   114.000000     0.000000
# 25%    1243.000000  1971.000000  1974.000000   190.000000     0.366000
# 50%    2486.000000  1990.000000  1995.000000   210.000000     0.423000
# 75%    3729.000000  2008.000000  2014.000000   225.000000     0.465000
# max    4972.000000  2022.000000  2022.000000   360.000000     1.000000
#
#        NBA_g_played      NBA_ppg      NBA_ft%  NBA_fg_per_game  \
# count   4973.000000  4973.000000  4728.000000      4973.000000
# mean     268.871104     6.385642     0.698962         2.438106
# std      310.179579     4.760793     0.140654         1.810070
# min        1.000000     0.000000     0.000000         0.000000
# 25%       31.000000     2.800000     0.633000         1.100000
# 50%      125.000000     5.200000     0.719000         2.000000
# 75%      446.000000     8.700000     0.784000         3.300000
# max     1611.000000    30.100000     1.000000        12.100000
#
#        NBA_fga_per_game  ...     NCAA_ppg      NCAA_ft    NCAA_fgpg  \
# count       4973.000000  ...  3287.000000  3280.000000  3287.000000
# mean           5.752202  ...    13.702677     0.714109     5.093094
# std            3.870099  ...     4.628367     0.089708     1.804854
# min            0.000000  ...     1.600000     0.295000     0.600000
# 25%            2.800000  ...    10.600000     0.662000     3.900000
# 50%            4.900000  ...    13.500000     0.722000     4.900000
# 75%            7.900000  ...    16.400000     0.773000     6.100000
# max           23.800000  ...    44.200000     1.745000    16.700000
#
#         NCAA_fgapg    NCAA_ftpg   NCAA_ftapg  NCAA__3ptpg  NCAA__3ptapg  \
# count  3259.000000  3287.000000  3279.000000  2042.000000   2042.000000
# mean     10.461829     2.922848     4.081610     0.913908      2.532321
# std       3.746143     1.268152     1.684578     0.801617      2.107385
# min       1.200000     0.300000     0.300000     0.000000      0.000000
# 25%       7.900000     2.100000     2.900000     0.100000      0.400000
# 50%      10.200000     2.800000     3.900000     0.800000      2.400000
# 75%      12.600000     3.600000     5.000000     1.500000      4.100000
# max      38.100000    10.800000    14.400000     4.000000     10.800000
#
#        NCAA__3ptpct  NCAA_efgpct
# count   2100.000000          0.0
# mean       0.323875          NaN
# std        0.132159          NaN
# min        0.000000          NaN
# 25%        0.298000          NaN
# 50%        0.348000          NaN
# 75%        0.383000          NaN
# max        1.000000          NaN
#
# [8 rows x 28 columns]

# %%
#columns with null values
players.isna().sum()
# Out:
# Unnamed: 0             0
# url                    0
# name                   0
# active_from            0
# active_to              0
# position               0
# college              351
# height                 0
# weight                 5
# birth_date            18
# NBA_fg%               36
# NBA_g_played           0
# NBA_ppg                0
# NBA_ft%              245
# NBA_fg_per_game        0
# NBA_fga_per_game       0
# NBA_ft_per_g           0
# NBA_fta_p_g            0
# NBA__3ptpg          1128
# NBA__3ptapg         1128
# NBA__3ptpct         1647
# NBA_efgpct          1158
# NCAA_fgpct          1714
# NCAA_games          1686
# NCAA_ppg            1686
# NCAA_ft             1693
# NCAA_fgpg           1686
# NCAA_fgapg          1714
# NCAA_ftpg           1686
# NCAA_ftapg          1694
# NCAA__3ptpg         2931
# NCAA__3ptapg        2931
# NCAA__3ptpct        2873
# NCAA_efgpct         4973
# PER                    0
# dtype: int64

# %% [markdown]
# Looking at the null values, we decided to drop the following columns.
#
# - **'NCAA_efgpct'**: collegiate effective field goal percentage which is null for all players.
#
# - **'Unnamed: 0'**: excess column that just has index.
#
#
# It should also be noted that there are 5 missing values for weight and 18 for birthdate which should not affect our analysis as we can most likely find the values to input with a google search.

# %%
#dropping columns
players = players.drop(columns = ['Unnamed: 0','NCAA_efgpct'], axis = 1)
players
# Out:
#                             url                 name  active_from  active_to  \
# 0     /players/a/abdelal01.html       Alaa Abdelnaby         1991       1995
# 1     /players/a/abdulza01.html      Zaid Abdul-Aziz         1969       1978
# 2     /players/a/abdulka01.html  Kareem Abdul-Jabbar         1970       1989
# 3     /players/a/abdulma02.html   Mahmoud Abdul-Rauf         1991       2001
# 4     /players/a/abdulta01.html    Tariq Abdul-Wahad         1998       2003
# ...                         ...                  ...          ...        ...
# 4968  /players/z/zizican01.html           Ante Žižić         2018       2020
# 4969   /players/z/zoetji01.html             Jim Zoet         1983       1983
# 4970   /players/z/zopfbi01.html            Bill Zopf         1971       1971
# 4971  /players/z/zubaciv01.html          Ivica Zubac         2017       2022
# 4972  /players/z/zunicma01.html           Matt Zunic         1949       1949
#
#      position                   college height  weight         birth_date  \
# 0         F-C                      Duke   6-10   240.0      June 24, 1968
# 1         C-F                Iowa State    6-9   235.0      April 7, 1946
# 2           C                      UCLA    7-2   225.0     April 16, 1947
# 3           G                       LSU    6-1   162.0      March 9, 1969
# 4           F  Michigan, San Jose State    6-6   223.0   November 3, 1974
# ...       ...                       ...    ...     ...                ...
# 4968      F-C                       NaN   6-10   266.0    January 4, 1997
# 4969        C     Kent State University    7-1   240.0  December 20, 1953
# 4970        G                  Duquesne    6-1   170.0       June 7, 1948
# 4971        C                       NaN    7-0   240.0     March 18, 1997
# 4972      G-F         George Washington    6-3   195.0  December 19, 1919
#
#       NBA_fg%  ...  NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  \
# 0       0.502  ...       8.5    0.728        3.3         5.6        1.8
# 1       0.428  ...      22.3    0.645        7.8        16.8        6.7
# 2       0.559  ...      26.4    0.628       10.7        16.8        5.0
# 3       0.442  ...      29.0    0.863       10.4        21.9        5.5
# 4       0.417  ...      13.6    0.726        4.9        10.4        3.2
# ...       ...  ...       ...      ...        ...         ...        ...
# 4968    0.581  ...       NaN      NaN        NaN         NaN        NaN
# 4969    0.200  ...       3.2    0.429        1.4         2.9        0.4
# 4970    0.363  ...       NaN      NaN        NaN         NaN        NaN
# 4971    0.592  ...       NaN      NaN        NaN         NaN        NaN
# 4972    0.303  ...       NaN      NaN        NaN         NaN        NaN
#
#       NCAA_ftapg  NCAA__3ptpg  NCAA__3ptapg  NCAA__3ptpct   PER
# 0            2.5          0.0           0.0           NaN  13.0
# 1           10.4          NaN           NaN           NaN  15.1
# 2            7.9          NaN           NaN           NaN  24.6
# 3            6.4          2.7           7.2         0.372  15.4
# 4            4.4          0.6           1.7         0.322  11.4
# ...          ...          ...           ...           ...   ...
# 4968         NaN          NaN           NaN           NaN  17.4
# 4969         1.0          NaN           NaN           NaN  -0.8
# 4970         NaN          NaN           NaN           NaN   9.6
# 4971         NaN          NaN           NaN           NaN  19.3
# 4972         NaN          NaN           NaN           NaN     -
#
# [4973 rows x 33 columns]

# %%
#finding who are the ones that have missing weight values
weight_missing = players[players['weight'].isnull() == True]
weight_missing_index = weight_missing.index
#dropping these players since its old and they didn't play for long. 
players = players.drop(index=weight_missing_index, axis=0).reset_index()

# %% [markdown]
# The weights of these players cannot be found anywhere. The time that they were active is also only up to a year where growth may not have been shown among their games. The time frame in which these players played is beyond the scope of our project since they played in the 50s and 60s so we will drop these values.

# %%
#finding birthdays that are missing
birthday_missing = players[players['birth_date'].isnull() == True]
#dropping these rows cause we can't find the birthdays for them and their active time frame is within the same year.
birthday_missing_index = birthday_missing.index
players = players.drop(index = birthday_missing_index, axis = 0).reset_index()

# %% [markdown]
# After looking at the missing birthdates and heights, these players are those that have played before the 1970's which is beyond the scope of our project. Therefore, they are not needed for our analysis so will be dropped as well.

# %%
#adding a column that tells us how long players play in NBA
players['years_played_NBA'] = players['active_to']-players['active_from']

# %%
#taking a look at the columns we have now
players.columns
# Out:
# Index(['level_0', 'index', 'url', 'name', 'active_from', 'active_to',
#        'position', 'college', 'height', 'weight', 'birth_date', 'NBA_fg%',
#        'NBA_g_played', 'NBA_ppg', 'NBA_ft%', 'NBA_fg_per_game',
#        'NBA_fga_per_game', 'NBA_ft_per_g', 'NBA_fta_p_g', 'NBA__3ptpg',
#        'NBA__3ptapg', 'NBA__3ptpct', 'NBA_efgpct', 'NCAA_fgpct', 'NCAA_games',
#        'NCAA_ppg', 'NCAA_ft', 'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg',
#        'NCAA_ftapg', 'NCAA__3ptpg', 'NCAA__3ptapg', 'NCAA__3ptpct', 'PER',
#        'years_played_NBA'],
#       dtype='object')

# %%
#putting into consistent data types
players.dtypes
# Out:
# level_0               int64
# index                 int64
# url                  object
# name                 object
# active_from           int64
# active_to             int64
# position             object
# college              object
# height               object
# weight              float64
# birth_date           object
# NBA_fg%             float64
# NBA_g_played          int64
# NBA_ppg             float64
# NBA_ft%             float64
# NBA_fg_per_game     float64
# NBA_fga_per_game    float64
# NBA_ft_per_g        float64
# NBA_fta_p_g         float64
# NBA__3ptpg          float64
# NBA__3ptapg         float64
# NBA__3ptpct         float64
# NBA_efgpct          float64
# NCAA_fgpct          float64
# NCAA_games          float64
# NCAA_ppg            float64
# NCAA_ft             float64
# NCAA_fgpg           float64
# NCAA_fgapg          float64
# NCAA_ftpg           float64
# NCAA_ftapg          float64
# NCAA__3ptpg         float64
# NCAA__3ptapg        float64
# NCAA__3ptpct        float64
# PER                  object
# years_played_NBA      int64
# dtype: object

# %%
#casting college column to string type
players['college'] = players['college'].astype(str)
#casting position to string type
players['position'] = players['position'].astype(str)
#casting height to int type
def height_inches(height):
    feet = int(height[0])
    inches = 0
    if len(height) == 4:
        inches = int(height[2:4] )
    if len(height) == 3:
        inches = int(height[2])
    return (feet * 12) + inches
players['height'] = players['height'].apply(height_inches)

# %%
#Since the birthdays are written out in readable format, we want something that we can work with in pandas.
players['birth_date']
# Out:
# 0           June 24, 1968
# 1           April 7, 1946
# 2          April 16, 1947
# 3           March 9, 1969
# 4        November 3, 1974
#               ...
# 4946      January 4, 1997
# 4947    December 20, 1953
# 4948         June 7, 1948
# 4949       March 18, 1997
# 4950    December 19, 1919
# Name: birth_date, Length: 4951, dtype: object

# %%
#changing written birthdates into numerical ones that we can manipulate in the dataframe
def birthdate(day):
    day = day.replace(',', '')
    day = day.lower()

    output = datetime.strptime(day, '%B %d %Y')
    return output.date()

players['birth_date'] = players['birth_date'].apply(birthdate)

# %%
players
# Out:
#       level_0  index                        url                 name  \
# 0           0      0  /players/a/abdelal01.html       Alaa Abdelnaby
# 1           1      1  /players/a/abdulza01.html      Zaid Abdul-Aziz
# 2           2      2  /players/a/abdulka01.html  Kareem Abdul-Jabbar
# 3           3      3  /players/a/abdulma02.html   Mahmoud Abdul-Rauf
# 4           4      4  /players/a/abdulta01.html    Tariq Abdul-Wahad
# ...       ...    ...                        ...                  ...
# 4946     4963   4968  /players/z/zizican01.html           Ante Žižić
# 4947     4964   4969   /players/z/zoetji01.html             Jim Zoet
# 4948     4965   4970   /players/z/zopfbi01.html            Bill Zopf
# 4949     4966   4971  /players/z/zubaciv01.html          Ivica Zubac
# 4950     4967   4972  /players/z/zunicma01.html           Matt Zunic
#
#       active_from  active_to position                   college  height  \
# 0            1991       1995      F-C                      Duke      82
# 1            1969       1978      C-F                Iowa State      81
# 2            1970       1989        C                      UCLA      86
# 3            1991       2001        G                       LSU      73
# 4            1998       2003        F  Michigan, San Jose State      78
# ...           ...        ...      ...                       ...     ...
# 4946         2018       2020      F-C                       nan      82
# 4947         1983       1983        C     Kent State University      85
# 4948         1971       1971        G                  Duquesne      73
# 4949         2017       2022        C                       nan      84
# 4950         1949       1949      G-F         George Washington      75
#
#       weight  ... NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  NCAA_ftapg  \
# 0      240.0  ...   0.728        3.3         5.6        1.8         2.5
# 1      235.0  ...   0.645        7.8        16.8        6.7        10.4
# 2      225.0  ...   0.628       10.7        16.8        5.0         7.9
# 3      162.0  ...   0.863       10.4        21.9        5.5         6.4
# 4      223.0  ...   0.726        4.9        10.4        3.2         4.4
# ...      ...  ...     ...        ...         ...        ...         ...
# 4946   266.0  ...     NaN        NaN         NaN        NaN         NaN
# 4947   240.0  ...   0.429        1.4         2.9        0.4         1.0
# 4948   170.0  ...     NaN        NaN         NaN        NaN         NaN
# 4949   240.0  ...     NaN        NaN         NaN        NaN         NaN
# 4950   195.0  ...     NaN        NaN         NaN        NaN         NaN
#
#       NCAA__3ptpg  NCAA__3ptapg  NCAA__3ptpct   PER  years_played_NBA
# 0             0.0           0.0           NaN  13.0                 4
# 1             NaN           NaN           NaN  15.1                 9
# 2             NaN           NaN           NaN  24.6                19
# 3             2.7           7.2         0.372  15.4                10
# 4             0.6           1.7         0.322  11.4                 5
# ...           ...           ...           ...   ...               ...
# 4946          NaN           NaN           NaN  17.4                 2
# 4947          NaN           NaN           NaN  -0.8                 0
# 4948          NaN           NaN           NaN   9.6                 0
# 4949          NaN           NaN           NaN  19.3                 5
# 4950          NaN           NaN           NaN     -                 0
#
# [4951 rows x 36 columns]

# %%
#cleaning up player columns
players = players.rename(columns={'name':'player_name','NBA_fg_per_game':'NBA_fgpg',
                        'NBA_fga_per_game':'NBA_fgapg','NBA_ft_per_g':'NBA_ftpg','NBA_fta_p_g':'NBA_ftapg',
                       'NBA__3ptpg':'NBA_3ptpg','NBA__3ptapg':'NBA_3ptapg','NBA__3ptpct':'NBA_3pt%',
                       'NBA_efgpct':'NBA_efg%','NCAA_fgpct':'NCAA_fg%','NCAA__3ptpg':'NCAA_3ptpg',
                       'NCAA__3ptapg':'NCAA_3ptapg','NCAA__3ptpct':'NCAA_3pt%','PER':'NBA_per'})
#organize the dataframe and relabel columns
columns = ['player_name','height','weight','birth_date','active_from','active_to','position',
           'years_played_NBA','college','NBA_g_played', 'NBA_per', 'NBA_fg%', 'NBA_ppg',
       'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg', 'NBA_ftpg',
       'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%', 'NBA_efg%',
       'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft', 'NCAA_fgpg',
       'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg', 'NCAA_3ptapg',
       'NCAA_3pt%']
players = players[columns]
players.head()
# Out:
#            player_name  height  weight  birth_date  active_from  active_to  \
# 0       Alaa Abdelnaby      82   240.0  1968-06-24         1991       1995
# 1      Zaid Abdul-Aziz      81   235.0  1946-04-07         1969       1978
# 2  Kareem Abdul-Jabbar      86   225.0  1947-04-16         1970       1989
# 3   Mahmoud Abdul-Rauf      73   162.0  1969-03-09         1991       2001
# 4    Tariq Abdul-Wahad      78   223.0  1974-11-03         1998       2003
#
#   position  years_played_NBA                   college  NBA_g_played  ...  \
# 0      F-C                 4                      Duke           256  ...
# 1      C-F                 9                Iowa State           505  ...
# 2        C                19                      UCLA          1560  ...
# 3        G                10                       LSU           586  ...
# 4        F                 5  Michigan, San Jose State           236  ...
#
#   NCAA_games  NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  NCAA_ftapg  \
# 0      134.0       8.5    0.728        3.3         5.6        1.8         2.5
# 1       75.0      22.3    0.645        7.8        16.8        6.7        10.4
# 2       88.0      26.4    0.628       10.7        16.8        5.0         7.9
# 3       64.0      29.0    0.863       10.4        21.9        5.5         6.4
# 4       87.0      13.6    0.726        4.9        10.4        3.2         4.4
#
#    NCAA_3ptpg  NCAA_3ptapg  NCAA_3pt%
# 0         0.0          0.0        NaN
# 1         NaN          NaN        NaN
# 2         NaN          NaN        NaN
# 3         2.7          7.2      0.372
# 4         0.6          1.7      0.322
#
# [5 rows x 33 columns]

# %%
#After renaming the columns, we are left with these renamed columns which we will use for our analysis.
players.columns
# Out:
# Index(['player_name', 'height', 'weight', 'birth_date', 'active_from',
#        'active_to', 'position', 'years_played_NBA', 'college', 'NBA_g_played',
#        'NBA_per', 'NBA_fg%', 'NBA_ppg', 'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg',
#        'NBA_ftpg', 'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%',
#        'NBA_efg%', 'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
#        'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
#        'NCAA_3ptapg', 'NCAA_3pt%'],
#       dtype='object')

# %%
#nba players that did not go to college
no_college = players[players['college'] == 'nan']
no_college

#add a new column that tells whether or not they went to college
def going_college(val):
    if val == 'nan':
        return False
    else:
        return True

players['go_college'] = players['college'].apply(going_college)

# %% [markdown]
# ## adjusting null values

# %% [markdown]
# The '3 point shot' was not adopted into the NBA until 1980. This means that players that played before this time cannot must not have shot a 3 point shot. So we can replace their null values with 0's since they didn't shoot a 3 point shot.
#
# The same applies for games for NCAA games,except that the NCAA adopted the 3 point shot in 1986.
#
#
#
# https://www.usab.com/youth/news/2011/06/the-history-of-the-3-pointer.aspx

# %%
# if they scored 0 field goals, free throws, 3 point, then their percentages are 0.
players.loc[((players['NBA_fg%'].isna()) & (players['NBA_fgpg'] == 0)), 'NBA_fg%'] = 0
players.loc[((players['NBA_ft%'].isna()) & (players['NBA_ftpg'] == 0)), 'NBA_ft%'] = 0
players.loc[((players['NBA_3pt%'].isna()) & (players['NBA_3ptpg'] == 0)), 'NBA_3pt%'] = 0
players.loc[((players['NBA_efg%'].isna()) & (players['NBA_fgpg'] == 0)), 'NBA_efg%'] = 0

# %%
# player years that did not have nba 3 point data
players[players['NBA_3ptpg'].isna()]['active_to'].sort_values().unique()
# Out:
# array([1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979])

# %%
players.columns
# Out:
# Index(['player_name', 'height', 'weight', 'birth_date', 'active_from',
#        'active_to', 'position', 'years_played_NBA', 'college', 'NBA_g_played',
#        'NBA_per', 'NBA_fg%', 'NBA_ppg', 'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg',
#        'NBA_ftpg', 'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%',
#        'NBA_efg%', 'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
#        'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
#        'NCAA_3ptapg', 'NCAA_3pt%', 'go_college'],
#       dtype='object')

# %%
# making 3 point shot values equal 0 since 3 point was not used before 1980 NBA games
players.loc[((players['NBA_3ptpg'].isna())&(players['active_from']<1980)), ['NBA_3ptpg','NBA_3pt%','NBA_3ptapg']] = 0

#making 3 point shot values equal to 0 since 3 point was not used before 1987 NCAA games
players.loc[((players['NCAA_3ptpg'].isna())&(players['active_from']<1987)), ['NCAA_3ptpg','NCAA_3ptapg', 'NCAA_3pt%']] = 0

# %%
players.isna().sum()
# Out:
# player_name            0
# height                 0
# weight                 0
# birth_date             0
# active_from            0
# active_to              0
# position               0
# years_played_NBA       0
# college                0
# NBA_g_played           0
# NBA_per                0
# NBA_fg%                0
# NBA_ppg                0
# NBA_ft%                0
# NBA_fgpg               0
# NBA_fgapg              0
# NBA_ftpg               0
# NBA_ftapg              0
# NBA_3ptpg              0
# NBA_3ptapg             0
# NBA_3pt%               0
# NBA_efg%            1091
# NCAA_fg%            1692
# NCAA_games          1664
# NCAA_ppg            1664
# NCAA_ft             1671
# NCAA_fgpg           1664
# NCAA_fgapg          1692
# NCAA_ftpg           1664
# NCAA_ftapg          1672
# NCAA_3ptpg           656
# NCAA_3ptapg          656
# NCAA_3pt%            617
# go_college             0
# dtype: int64

# %%
#players that did not go to college and have null ncaa games, meaning they did not play in the NCAA
players.loc[((players['go_college'] == False)&(players['NCAA_games'].isna())), ['NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
       'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
       'NCAA_3ptapg', 'NCAA_3pt%']] = 0

# %%
players[players['NCAA_3ptpg'].isna()]
# Out:
#            player_name  height  weight  birth_date  active_from  active_to  \
# 13          Mark Acres      83   220.0  1962-11-15         1988       1993
# 24      Rafael Addison      79   215.0  1964-07-22         1987       1997
# 40         Mark Alarie      80   217.0  1963-12-11         1987       1991
# 56        Steve Alford      74   183.0  1964-11-23         1988       1991
# 66         Randy Allen      80   220.0  1965-01-26         1989       1990
# ...                ...     ...     ...         ...          ...        ...
# 4890       Brad Wright      83   225.0  1962-03-26         1987       1988
# 4896     Howard Wright      80   220.0  1967-12-20         1991       1993
# 4910       A.J. Wynder      74   180.0  1964-09-11         1991       1991
# 4924       Perry Young      77   210.0  1963-08-04         1987       1987
# 4940  Phil Zevenbergen      82   230.0  1964-04-13         1988       1988
#
#      position  years_played_NBA                                 college  \
# 13        F-C                 5                            Oral Roberts
# 24        F-G                10                                Syracuse
# 40          F                 4                                    Duke
# 56          G                 3                                 Indiana
# 66          F                 1                           Florida State
# ...       ...               ...                                     ...
# 4890        F                 1                                    UCLA
# 4896        F                 2                                Stanford
# 4910        G                 0                        UMass, Fairfield
# 4924        G                 0                           Virginia Tech
# 4940        C                 0  Seattle Pacific University, Washington
#
#       NBA_g_played  ... NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  \
# 13             375  ...     18.5    0.696        7.3        12.9        4.0
# 24             379  ...     14.9    0.763        6.2        11.6        2.5
# 40             325  ...     16.1    0.797        6.2        11.3        3.6
# 56             169  ...     19.5    0.898        7.2        13.5        4.3
# 66              70  ...     12.5    0.615        5.1        10.5        2.2
# ...            ...  ...      ...      ...        ...         ...        ...
# 4890            16  ...      5.6    0.617        2.1         4.0        1.4
# 4896            19  ...     12.9    0.630        4.8         8.6        3.3
# 4910             6  ...     11.1    0.832        4.1         8.3        2.8
# 4924             9  ...     14.7    0.689        5.6        10.8        3.5
# 4940             8  ...     10.1    0.721        3.8         7.6        2.5
#
#       NCAA_ftapg  NCAA_3ptpg  NCAA_3ptapg  NCAA_3pt%  go_college
# 13           5.7         NaN          NaN        NaN        True
# 24           3.3         NaN          NaN        NaN        True
# 40           4.5         NaN          NaN      0.000        True
# 56           4.8         NaN          NaN      0.530        True
# 66           3.6         NaN          NaN      0.000        True
# ...          ...         ...          ...        ...         ...
# 4890         2.3         NaN          NaN        NaN        True
# 4896         5.3         NaN          NaN      0.000        True
# 4910         3.3         NaN          NaN      0.286        True
# 4924         5.1         NaN          NaN        NaN        True
# 4940         3.5         NaN          NaN      0.000        True
#
# [337 rows x 34 columns]

# %%
#calculating efg%
def efg_calculate(df):
    fg = df['NBA_pg']
    three_point = df['NBA_3ptpg']
    fga = df['NBA_fgapg']
    return (fg + 0.5 * three_point) / fga

# %%
players.iloc[1]
# Out:
# player_name         Zaid Abdul-Aziz
# height                           81
# weight                        235.0
# birth_date               1946-04-07
# active_from                    1969
# active_to                      1978
# position                        C-F
# years_played_NBA                  9
# college                  Iowa State
# NBA_g_played                    505
# NBA_per                        15.1
# NBA_fg%                       0.428
# NBA_ppg                         9.0
# NBA_ft%                       0.728
# NBA_fgpg                        3.5
# NBA_fgapg                       8.2
# NBA_ftpg                        2.0
# NBA_ftapg                       2.8
# NBA_3ptpg                       0.0
# NBA_3ptapg                      0.0
# NBA_3pt%                        0.0
# NBA_efg%                        NaN
# NCAA_fg%                      0.465
# NCAA_games                     75.0
# NCAA_ppg                       22.3
# NCAA_ft                       0.645
# NCAA_fgpg                       7.8
# NCAA_fgapg                     16.8
# NCAA_ftpg                       6.7
# NCAA_ftapg                     10.4
# NCAA_3ptpg                      0.0
# NCAA_3ptapg                     0.0
# NCAA_3pt%                       0.0
# go_college                     True
# Name: 1, dtype: object

# %%
players[players['NBA_efg%'].isna()]
# Out:
#           player_name  height  weight  birth_date  active_from  active_to  \
# 1     Zaid Abdul-Aziz      81   235.0  1946-04-07         1969       1978
# 8      John Abramovic      75   195.0  1919-02-09         1947       1948
# 12       Don Ackerman      72   183.0  1930-09-04         1954       1954
# 14          Bud Acton      78   210.0  1942-01-11         1968       1968
# 27       Rick Adelman      73   175.0  1946-06-16         1969       1975
# ...               ...     ...     ...         ...          ...        ...
# 4932     Zeke Zawoluk      79   215.0  1930-10-13         1953       1955
# 4934      Dave Zeller      73   175.0  1939-06-08         1962       1962
# 4936     Harry Zeller      76   210.0  1919-07-10         1947       1947
# 4948        Bill Zopf      73   170.0  1948-06-07         1971       1971
# 4950       Matt Zunic      75   195.0  1919-12-19         1949       1949
#
#      position  years_played_NBA                         college  NBA_g_played  \
# 1         C-F                 9                      Iowa State           505
# 8           F                 1                Salem University            56
# 12          G                 0          Long Island University            28
# 14          F                 0               Hillsdale College            23
# 27          G                 6                Loyola Marymount           462
# ...       ...               ...                             ...           ...
# 4932      F-C                 2                      St. John's           179
# 4934        G                 0                Miami University            61
# 4936      C-F                 0  Washington & Jefferson College            48
# 4948        G                 0                        Duquesne            53
# 4950      G-F                 0               George Washington            56
#
#       ... NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  NCAA_ftapg  \
# 1     ...     22.3    0.645        7.8        16.8        6.7        10.4
# 8     ...      NaN      NaN        NaN         NaN        NaN         NaN
# 12    ...      NaN      NaN        NaN         NaN        NaN         NaN
# 14    ...      NaN      NaN        NaN         NaN        NaN         NaN
# 27    ...     18.6    0.809        6.3        15.1        6.2         7.7
# ...   ...      ...      ...        ...         ...        ...         ...
# 4932  ...      NaN      NaN        NaN         NaN        NaN         NaN
# 4934  ...      NaN      NaN        NaN         NaN        NaN         NaN
# 4936  ...      NaN      NaN        NaN         NaN        NaN         NaN
# 4948  ...      NaN      NaN        NaN         NaN        NaN         NaN
# 4950  ...      NaN      NaN        NaN         NaN        NaN         NaN
#
#       NCAA_3ptpg  NCAA_3ptapg  NCAA_3pt%  go_college
# 1            0.0          0.0        0.0        True
# 8            0.0          0.0        0.0        True
# 12           0.0          0.0        0.0        True
# 14           0.0          0.0        0.0        True
# 27           0.0          0.0        0.0        True
# ...          ...          ...        ...         ...
# 4932         0.0          0.0        0.0        True
# 4934         0.0          0.0        0.0        True
# 4936         0.0          0.0        0.0        True
# 4948         0.0          0.0        0.0        True
# 4950         0.0          0.0        0.0        True
#
# [1091 rows x 34 columns]

# %%
players[players['NCAA_3ptpg'].isna()]
# Out:
#            player_name  height  weight  birth_date  active_from  active_to  \
# 13          Mark Acres      83   220.0  1962-11-15         1988       1993
# 24      Rafael Addison      79   215.0  1964-07-22         1987       1997
# 40         Mark Alarie      80   217.0  1963-12-11         1987       1991
# 56        Steve Alford      74   183.0  1964-11-23         1988       1991
# 66         Randy Allen      80   220.0  1965-01-26         1989       1990
# ...                ...     ...     ...         ...          ...        ...
# 4890       Brad Wright      83   225.0  1962-03-26         1987       1988
# 4896     Howard Wright      80   220.0  1967-12-20         1991       1993
# 4910       A.J. Wynder      74   180.0  1964-09-11         1991       1991
# 4924       Perry Young      77   210.0  1963-08-04         1987       1987
# 4940  Phil Zevenbergen      82   230.0  1964-04-13         1988       1988
#
#      position  years_played_NBA                                 college  \
# 13        F-C                 5                            Oral Roberts
# 24        F-G                10                                Syracuse
# 40          F                 4                                    Duke
# 56          G                 3                                 Indiana
# 66          F                 1                           Florida State
# ...       ...               ...                                     ...
# 4890        F                 1                                    UCLA
# 4896        F                 2                                Stanford
# 4910        G                 0                        UMass, Fairfield
# 4924        G                 0                           Virginia Tech
# 4940        C                 0  Seattle Pacific University, Washington
#
#       NBA_g_played  ... NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  \
# 13             375  ...     18.5    0.696        7.3        12.9        4.0
# 24             379  ...     14.9    0.763        6.2        11.6        2.5
# 40             325  ...     16.1    0.797        6.2        11.3        3.6
# 56             169  ...     19.5    0.898        7.2        13.5        4.3
# 66              70  ...     12.5    0.615        5.1        10.5        2.2
# ...            ...  ...      ...      ...        ...         ...        ...
# 4890            16  ...      5.6    0.617        2.1         4.0        1.4
# 4896            19  ...     12.9    0.630        4.8         8.6        3.3
# 4910             6  ...     11.1    0.832        4.1         8.3        2.8
# 4924             9  ...     14.7    0.689        5.6        10.8        3.5
# 4940             8  ...     10.1    0.721        3.8         7.6        2.5
#
#       NCAA_ftapg  NCAA_3ptpg  NCAA_3ptapg  NCAA_3pt%  go_college
# 13           5.7         NaN          NaN        NaN        True
# 24           3.3         NaN          NaN        NaN        True
# 40           4.5         NaN          NaN      0.000        True
# 56           4.8         NaN          NaN      0.530        True
# 66           3.6         NaN          NaN      0.000        True
# ...          ...         ...          ...        ...         ...
# 4890         2.3         NaN          NaN        NaN        True
# 4896         5.3         NaN          NaN      0.000        True
# 4910         3.3         NaN          NaN      0.286        True
# 4924         5.1         NaN          NaN        NaN        True
# 4940         3.5         NaN          NaN      0.000        True
#
# [337 rows x 34 columns]

# %% [markdown]
# The '3 point shot' was not adopted into the NBA until 1980. This means that players that played before this time cannot must not have shot a 3 point shot. So we can replace their null values with 0's since they didn't shoot a 3 point shot.
#
# The same applies for games for NCAA games,except that the NCAA adopted the 3 point shot in 1986.
#
#
#
# https://www.usab.com/youth/news/2011/06/the-history-of-the-3-pointer.aspx

# %%
#many players listed here did not play in the NCAA, but went to college. A vast majority instead played in the junior college basketball league,played in another country, or signed with different leagues.
players[(players['NCAA_games'].isna())&(players['go_college']==True)].sort_values('active_from')
# Out:
#            player_name  height  weight  birth_date  active_from  active_to  \
# 8       John Abramovic      75   195.0  1919-02-09         1947       1948
# 2759    Press Maravich      72   185.0  1915-08-29         1947       1947
# 2748  Frank Mangiapane      70   195.0  1925-08-05         1947       1947
# 2729      John Mahnken      80   220.0  1922-06-16         1947       1953
# 2688         Al Lujack      75   220.0  1920-10-05         1947       1947
# ...                ...     ...     ...         ...          ...        ...
# 4309     Jared Terrell      75   227.0  1995-02-10         2019       2019
# 4313     Emanuel Terry      81   220.0  1996-08-21         2019       2019
# 4327    Brodric Thomas      77   185.0  1997-01-28         2021       2022
# 3934        Jay Scrubb      77   220.0  2000-09-01         2021       2022
# 2747        Karim Mané      75   190.0  2000-05-16         2021       2021
#
#      position  years_played_NBA                  college  NBA_g_played  ...  \
# 8           F                 1         Salem University            56  ...
# 2759        G                 0   Davis & Elkins College            51  ...
# 2748        G                 0                      NYU             6  ...
# 2729        C                 6               Georgetown           414  ...
# 2688        F                 0               Georgetown             5  ...
# ...       ...               ...                      ...           ...  ...
# 4309        G                 0             Rhode Island            14  ...
# 4313        F                 0         Lincoln Memorial             3  ...
# 4327        G                 1  Truman State University            34  ...
# 3934      G-F                 1    John A. Logan College            10  ...
# 2747        G                 0           Vanier College            10  ...
#
#      NCAA_ppg  NCAA_ft  NCAA_fgpg  NCAA_fgapg  NCAA_ftpg  NCAA_ftapg  \
# 8         NaN      NaN        NaN         NaN        NaN         NaN
# 2759      NaN      NaN        NaN         NaN        NaN         NaN
# 2748      NaN      NaN        NaN         NaN        NaN         NaN
# 2729      NaN      NaN        NaN         NaN        NaN         NaN
# 2688      NaN      NaN        NaN         NaN        NaN         NaN
# ...       ...      ...        ...         ...        ...         ...
# 4309      NaN      NaN        NaN         NaN        NaN         NaN
# 4313      NaN      NaN        NaN         NaN        NaN         NaN
# 4327      NaN      NaN        NaN         NaN        NaN         NaN
# 3934      NaN      NaN        NaN         NaN        NaN         NaN
# 2747      NaN      NaN        NaN         NaN        NaN         NaN
#
#       NCAA_3ptpg  NCAA_3ptapg  NCAA_3pt%  go_college
# 8            0.0          0.0        0.0        True
# 2759         0.0          0.0        0.0        True
# 2748         0.0          0.0        0.0        True
# 2729         0.0          0.0        0.0        True
# 2688         0.0          0.0        0.0        True
# ...          ...          ...        ...         ...
# 4309         NaN          NaN        NaN        True
# 4313         NaN          NaN        NaN        True
# 4327         NaN          NaN        NaN        True
# 3934         NaN          NaN        NaN        True
# 2747         NaN          NaN        NaN        True
#
# [1313 rows x 34 columns]

# %%
players.columns
# Out:
# Index(['player_name', 'height', 'weight', 'birth_date', 'active_from',
#        'active_to', 'position', 'years_played_NBA', 'college', 'NBA_g_played',
#        'NBA_per', 'NBA_fg%', 'NBA_ppg', 'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg',
#        'NBA_ftpg', 'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%',
#        'NBA_efg%', 'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
#        'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
#        'NCAA_3ptapg', 'NCAA_3pt%', 'go_college'],
#       dtype='object')

# %%
#players that did not play in ncaa should have ncaa_games be at 0
no_ncaa_games = players[(players['NCAA_games'].isna())]
players.loc[((players['NCAA_games'].isna())), ['NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
       'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
       'NCAA_3ptapg', 'NCAA_3pt%']] = 0

# %%
players.isna().sum()
# Out:
# player_name            0
# height                 0
# weight                 0
# birth_date             0
# active_from            0
# active_to              0
# position               0
# years_played_NBA       0
# college                0
# NBA_g_played           0
# NBA_per                0
# NBA_fg%                0
# NBA_ppg                0
# NBA_ft%                0
# NBA_fgpg               0
# NBA_fgapg              0
# NBA_ftpg               0
# NBA_ftapg              0
# NBA_3ptpg              0
# NBA_3ptapg             0
# NBA_3pt%               0
# NBA_efg%            1091
# NCAA_fg%              28
# NCAA_games             0
# NCAA_ppg               0
# NCAA_ft                8
# NCAA_fgpg              0
# NCAA_fgapg            28
# NCAA_ftpg              0
# NCAA_ftapg             8
# NCAA_3ptpg           269
# NCAA_3ptapg          269
# NCAA_3pt%            230
# go_college             0
# dtype: int64

# %%
#if player data was not able to be retrieved by web scraper
players = players.dropna(axis = 0)

# %%
players.isna().sum()
# Out:
# player_name         0
# height              0
# weight              0
# birth_date          0
# active_from         0
# active_to           0
# position            0
# years_played_NBA    0
# college             0
# NBA_g_played        0
# NBA_per             0
# NBA_fg%             0
# NBA_ppg             0
# NBA_ft%             0
# NBA_fgpg            0
# NBA_fgapg           0
# NBA_ftpg            0
# NBA_ftapg           0
# NBA_3ptpg           0
# NBA_3ptapg          0
# NBA_3pt%            0
# NBA_efg%            0
# NCAA_fg%            0
# NCAA_games          0
# NCAA_ppg            0
# NCAA_ft             0
# NCAA_fgpg           0
# NCAA_fgapg          0
# NCAA_ftpg           0
# NCAA_ftapg          0
# NCAA_3ptpg          0
# NCAA_3ptapg         0
# NCAA_3pt%           0
# go_college          0
# dtype: int64

# %% [markdown]
# We were unable to find the remaining null value data for NCAA players. This may be due to players not playing in the NCAA in the first place.

# %% [markdown]
# From looking at this subset of the dataset, we can see that there are 348 players that did not go to college who have played in the NBA. This means that these players could have went straight to the league directly from high school or are players from other countries.

# %% [markdown]
# ## EDA / plots

# %%
#visualize the distribution of variables

players.hist(edgecolor = 'black', linewidth = 1, figsize = (30,30))
# Out:
# array([[<AxesSubplot:title={'center':'height'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'active_from'}>,
#         <AxesSubplot:title={'center':'active_to'}>,
#         <AxesSubplot:title={'center':'years_played_NBA'}>],
#        [<AxesSubplot:title={'center':'NBA_g_played'}>,
#         <AxesSubplot:title={'center':'NBA_fg%'}>,
#         <AxesSubplot:title={'center':'NBA_ppg'}>,
#         <AxesSubplot:title={'center':'NBA_ft%'}>,
#         <AxesSubplot:title={'center':'NBA_fgpg'}>],
#        [<AxesSubplot:title={'center':'NBA_fgapg'}>,
#         <AxesSubplot:title={'center':'NBA_ftpg'}>,
#         <AxesSubplot:title={'center':'NBA_ftapg'}>,
#         <AxesSubplot:title={'center':'NBA_3ptpg'}>,
#         <AxesSubplot:title={'center':'NBA_3ptapg'}>],
#        [<AxesSubplot:title={'center':'NBA_3pt%'}>,
#         <AxesSubplot:title={'center':'NBA_efg%'}>,
#         <AxesSubplot:title={'center':'NCAA_fg%'}>,
#         <AxesSubplot:title={'center':'NCAA_games'}>,
#         <AxesSubplot:title={'center':'NCAA_ppg'}>],
#        [<AxesSubplot:title={'center':'NCAA_ft'}>,
#         <AxesSubplot:title={'center':'NCAA_fgpg'}>,
#         <AxesSubplot:title={'center':'NCAA_fgapg'}>,
#         <AxesSubplot:title={'center':'NCAA_ftpg'}>,
#         <AxesSubplot:title={'center':'NCAA_ftapg'}>],
#        [<AxesSubplot:title={'center':'NCAA_3ptpg'}>,
#         <AxesSubplot:title={'center':'NCAA_3ptapg'}>,
#         <AxesSubplot:title={'center':'NCAA_3pt%'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#distribution of height with more bins
sns.histplot(data = players['height'], bins = 28)
sns.set(rc={'figure.figsize':(8,8)})

# %% [markdown]
# From the graph on the distribution of heights, players heights is roughly a normal distribution. The minimum in height is around 66 inches and the maximum of heights is around 91 inches. To convert it back to feet this would be 5 feet 5 inches and 7 feet 5 inches.

# %%
#distribution in weight
sns.histplot(data = players['weight'], bins = 28)
sns.set(rc={'figure.figsize':(8,8)})

# %% [markdown]
# Looking at the graph of the distribution in weight, it can be noticed that this is also a histogram that is normally distributed. There does seem to be a slight right skew. This is most likely due to weights being more distributed among heavier players.

# %%
#relation in games played in NBA and efg% (effective field goal percent)
sns.lmplot(x = 'NBA_g_played', y = 'NBA_efg%', data = players)

# %% [markdown]
# Plotting the NBA games that players have played against their NBA effective field goal percentage shows that there is a linear correlation between these two variables. This can mean that as players get more experience playing games that they get a higher percentage. To further analyze this, we will look at their scoring as well.

# %%
#correlation between games played and free throws
sns.lmplot(x = 'NBA_g_played', y = 'NBA_ftpg', data = players)

# %%
#correlation between games played and 3 point shots
sns.lmplot(x = 'NBA_g_played', y = 'NBA_3ptpg', data = players)

# %%
#correlation between games played and points scored overall
sns.lmplot(x = 'NBA_g_played', y = 'NBA_ppg', data = players)

# %%
#relation between weight and efg%
sns.lmplot(x = 'weight', y = 'NBA_efg%', data = players)

# %%
#relation between weight and NBA games played
sns.lmplot(x = 'weight', y = 'NBA_g_played', data = players)

# %%
#relation between college games played and NBA
sns.lmplot(x = 'NCAA_games', y = 'NBA_g_played', data = players)

# %%
#relation between points per game and the number of games that they played in NBA based on players that did not go to college
sns.lmplot(y = 'NBA_ppg',x = 'NBA_g_played',data = no_college)

# %% [markdown]
# Looking at the results of the graph that plots points per game and the number of games that they play based on players that did not go to college, there is a strong positive linear correlation between these variables.

# %%
#relation between points scored in NCAA games and NBA games
sns.lmplot( x='NCAA_ppg', y='NBA_ppg', data=players)

# %% [markdown]
# As players scored more in their collegiate games, there is a strong positive correlation with scoring more points in the NBA as well. This is something that we plan on looking more into in our project.

# %% [markdown]
# ### Perhaps the position of the player affect how often they play which could influence scoring and ratings?
#
# In this part, we wanted to look at whether or not playing a particular position influneces the frequency that a player is put in. How often a player is put into the game determines how often they can play which alters the chances they have at scoring more/less as compared to other players.

# %%
sns.barplot(x ='position', y = 'NBA_g_played', data = players)
# Out:
# <AxesSubplot:xlabel='position', ylabel='NBA_g_played'>

# %%
sns.barplot(x='position', y = 'NCAA_games', data = players)
# Out:
# <AxesSubplot:xlabel='position', ylabel='NCAA_games'>

# %% [markdown]
# We can see that the position of players in the NBA is not as uniform as when they play in college. There is a uniform distribution among college player positions and the number of games whereas, F-C, C-F, F-G play more than the other positions in the NBA.

# %%
players.columns
# Out:
# Index(['player_name', 'height', 'weight', 'birth_date', 'active_from',
#        'active_to', 'position', 'years_played_NBA', 'college', 'NBA_g_played',
#        'NBA_per', 'NBA_fg%', 'NBA_ppg', 'NBA_ft%', 'NBA_fgpg', 'NBA_fgapg',
#        'NBA_ftpg', 'NBA_ftapg', 'NBA_3ptpg', 'NBA_3ptapg', 'NBA_3pt%',
#        'NBA_efg%', 'NCAA_fg%', 'NCAA_games', 'NCAA_ppg', 'NCAA_ft',
#        'NCAA_fgpg', 'NCAA_fgapg', 'NCAA_ftpg', 'NCAA_ftapg', 'NCAA_3ptpg',
#        'NCAA_3ptapg', 'NCAA_3pt%', 'go_college'],
#       dtype='object')

# %% [markdown]
# # Model
